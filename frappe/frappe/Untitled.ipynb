# %%
trn, tst, val = [], [], []
columns="label,user,item,daytime,weekday,isweekend,homework,cost,weather,country,city"
with open("frappe.train.libfm", "r") as fin, \
    open("frappe.train.csv", "w") as fout:
    fout.write(columns + "\n")
    for line in fin.readlines():
        line = line.strip().split(" ")
        line = ["0" if line[0] == "-1" else "1"] + [line[x][:-2] for x in range(1,len(line))]
        fout.write(",".join(line) + "\n")

with open("frappe.test.libfm", "r") as fin, \
    open("frappe.test.csv", "w") as fout:
    fout.write(columns + "\n")
    for line in fin.readlines():
        line = line.strip().split(" ")
        line = ["0" if line[0]== "-1" else "1"] \
               + [line[x][:-2] for x in range(1,len(line))]
        fout.write(",".join(line) + "\n")
        
with open("frappe.validation.libfm", "r") as fin, \
    open("frappe.train.csv", "w") as fout:
    fout.write(columns + "\n")
    for line in fin.readlines():
        line = line.strip().split(" ")
        line = ["0" if line[0]== "-1" else "1"] \
               + [line[x][:-2] for x in range(1,len(line))]
        fout.write(",".join(line) + "\n")

# %%
print(s)
# Out:
# {('187', '2178'), ('32', '3946'), ('32', '4716'), ('78', '2759'), ('121', '1111'), ('53', '2175'), ('579', '4123'), ('168', '2959'), ('359', '4303'), ('89', '3869'), ('444', '2783'), ('447', '4474'), ('186', '1434'), ('499', '975'), ('482', '1194'), ('412', '3187'), ('59', '1707'), ('158', '3538'), ('423', '1885'), ('64', '1537'), ('172', '4965'), ('37', '4157'), ('377', '3462'), ('273', '4255'), ('16', '4324'), ('51', '3722'), ('81', '3686'), ('123', '2423'), ('117', '1985'), ('66', '1006'), ('60', '1760'), ('282', '1546'), ('165', '1509'), ('272', '4641'), ('29', '3574'), ('49', '3243'), ('250', '1530'), ('260', '4403'), ('358', '3080'), ('401', '4331'), ('262', '4930'), ('169', '2324'), ('90', '3090'), ('275', '3143'), ('273', '2539'), ('175', '3046'), ('294', '4513'), ('34', '4851'), ('133', '1296'), ('68', '2031'), ('275', '4554'), ('247', '2945'), ('243', '1283'), ('194', '3293'), ('204', '2351'), ('191', '4076'), ('54', '4947'), ('432', '3545'), ('134', '3629'), ('303', '2642'
# ...
